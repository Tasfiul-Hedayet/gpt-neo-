# %% [markdown]
# <a href="https://colab.research.google.com/github/Tasfiul-Hedayet/gpt-neo-/blob/main/GPT_Neo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing and importing dependencies

# %%
# !pip3 install torch>=2.0.1+cu117 torchvision>=0.15.1+cu117 -f https://download.pytorch.org/whl/cu117/torch_stable.html

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 38.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %% [markdown]
# Setting up the generator

# %%
generator = pipeline('text-generation', model ='EleutherAI/gpt-neo-125M')

# %% [markdown]
# Generating text

# %%
post = "This is my first blog post, I'm really excited!"

# %%
result = generator(post, max_length=50, do_sample=True, temperature=0.9)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
result
# Out:
# [{'generated_text': 'This is my first blog post, I\'m really excited! I found this site online because I had a "very bad day" and I was trying to start writing another one! So here it is!\n\nFor this week\'s blog, I'}]

# %% [markdown]
# Integration with the Gradio App

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 7.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

# %%
def generate(post):
    results = generator(post, max_length=50, do_sample=True, temperature=0.9)
    return results

# %%
blog_inputs = gr.inputs.Textbox(lines=3, placeholder="Enter post to generate posts...")
# Out:
# <ipython-input-24-9b8077e9a8a3>:1: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   blog_inputs = gr.inputs.Textbox(lines=3, placeholder="Enter post to generate posts...")
# <ipython-input-24-9b8077e9a8a3>:1: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   blog_inputs = gr.inputs.Textbox(lines=3, placeholder="Enter post to generate posts...")
# <ipython-input-24-9b8077e9a8a3>:1: GradioDeprecationWarning: `numeric` parameter is deprecated, and it has no effect
#   blog_inputs = gr.inputs.Textbox(lines=3, placeholder="Enter post to generate posts...")

# %%
interface = gr.Interface(fn=generate,
                        inputs=blog_inputs,
                        outputs='text',
                        title='AI based blog content generator')

# %%
interface.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
